# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from os.path import join
import matplotlib

from write_read_cache import store_data, read_data
from read_events import read_events, get_events

cache_folder = "cache/muons"

# %%
# Import muon data

# -40 C, 10 mbar
events_m40_10mbar = read_events(
    r"C:\Users\ghisl\Google Drive UniBG\UniBG\CORSI\PhD\GAPS\INFN_Napoli\TVAC_test\GAPS_Test_CIRA\muoni\muoni_2_T_-40C_p_10_mbar.txt",
    2,
)
store_data(events_m40_10mbar, "events_m40_10mbar", cache_folder)

# -40 C, 6 mbar
events_m40_6mbar = read_events(
    r"C:\Users\ghisl\Google Drive UniBG\UniBG\CORSI\PhD\GAPS\INFN_Napoli\TVAC_test\GAPS_Test_CIRA\muoni\muoni_5_T_-40C_p_06_mbar.txt",
    2,
)
store_data(events_m40_6mbar, "events_m40_6mbar", cache_folder)

# -40 C, 3 mbar
events_m40_3mbar = read_events(
    r"C:\Users\ghisl\Google Drive UniBG\UniBG\CORSI\PhD\GAPS\INFN_Napoli\TVAC_test\GAPS_Test_CIRA\muoni\muoni_6_T_-40C_p_03_mbar.txt",
    2,
)
store_data(events_m40_3mbar, "events_m40_3mbar", cache_folder)

# -50 C, 3 mbar
events_m50_3mbar = read_events(
    r"C:\Users\ghisl\Google Drive UniBG\UniBG\CORSI\PhD\GAPS\INFN_Napoli\TVAC_test\GAPS_Test_CIRA\muoni\muoni_8_T_-50C_p_03_mbar.txt",
    2,
)
store_data(events_m50_3mbar, "events_m50_3mbar", cache_folder)

# -50 C, 6 mbar
events_m50_6mbar = read_events(
    r"C:\Users\ghisl\Google Drive UniBG\UniBG\CORSI\PhD\GAPS\INFN_Napoli\TVAC_test\GAPS_Test_CIRA\muoni\muoni_10_T_-50C_p_06_mbar.txt",
    2,
)
store_data(events_m50_6mbar, "events_m50_6mbar", cache_folder)

# -50 C, 10 mbar
events_m50_10mbar = read_events(
    r"C:\Users\ghisl\Google Drive UniBG\UniBG\CORSI\PhD\GAPS\INFN_Napoli\TVAC_test\GAPS_Test_CIRA\muoni\muoni_12_T_-50C_p_10_mbar.txt",
    2,
)
store_data(events_m50_10mbar, "events_m50_10mbar", cache_folder)

# 0 C, 3 mbar
events_0_3mbar = read_events(
    r"C:\Users\ghisl\Google Drive UniBG\UniBG\CORSI\PhD\GAPS\INFN_Napoli\TVAC_test\GAPS_Test_CIRA\muoni\muoni_15_T_0C_p_03_mbar.txt",
    2,
)
store_data(events_0_3mbar, "events_0_3mbar", cache_folder)
# Out:
#          Events in file:  5859
#             Real events:  5855
#  All negative saturated:  0
# Some negative saturated:  1536
#  All positive saturated:  0
# Some positive saturated:  0
#                Selected:  4319
#          Events in file:  5415
#             Real events:  5408
#  All negative saturated:  0
# Some negative saturated:  1368
#  All positive saturated:  0
# Some positive saturated:  0
#                Selected:  4040
#          Events in file:  5663
#             Real events:  5656
#  All negative saturated:  0
# Some negative saturated:  1385
#  All positive saturated:  0
# Some positive saturated:  0
#                Selected:  4271
#          Events in file:  4305
#             Real events:  4301
#  All negative saturated:  0
# Some negative saturated:  1125
#  All positive saturated:  0
# Some positive saturated:  0
#                Selected:  3176
#          Events in file:  4144
#             Real events:  4141
#  All negative saturated:  0
# ...

# %%
# Plot muons - 50 C and 3 mbar

events_m50_3mbar = read_data("events_m50_3mbar", cache_folder)
channels = range(0, 32)
matplotlib.rcParams["figure.figsize"] = [8 * 4, 6 * 3]
plt.clf()
for ch in channels:
    plt.subplot(4, 8, ch + 1)
    muons_ch = get_events(events_m50_3mbar, ch)
    plt.hist(muons_ch, bins=np.arange(min(muons_ch), max(muons_ch), 1))
    plt.yscale("log")
    plt.xlim([0, 1000])
    plt.xlabel("Energy [ADU]")

plt.show()

# %%
# Plot muons as sum of all channels
events_m50_3mbar = read_data("events_m50_3mbar", cache_folder)
channels = range(0, 32)
matplotlib.rcParams["figure.figsize"] = [8, 6]

events_allch = np.array(events_m50_3mbar).flatten()

plt.clf()
plt.hist(events_allch, bins=range(0, 1000))
plt.yscale("log")
plt.xlim([0, 1000])
plt.xlabel("Energy [ADU]")
plt.ylabel("Occurrences")
plt.title("Muon acquisition with THR 130 @ -50 °C and 3 mbar (all channels)")
plt.show()

# %%
# Plot muons as sum of all channels
events_m50_6mbar = read_data("events_m50_6mbar", cache_folder)
channels = range(0, 32)
matplotlib.rcParams["figure.figsize"] = [8, 6]

events_allch = np.array(events_m50_6mbar).flatten()

plt.clf()
plt.hist(events_allch, bins=range(0, 1000))
plt.yscale("log")
plt.xlim([0, 1000])
plt.xlabel("Energy [ADU]")
plt.ylabel("Occurrences")
plt.title("Muon acquisition with THR 130 @ -50 °C and 6 mbar (all channels)")
plt.show()

# %%
# Plot muons as sum of all channels
events_m50_10mbar = read_data("events_m50_10mbar", cache_folder)
channels = range(0, 32)
matplotlib.rcParams["figure.figsize"] = [8, 6]

events_allch = np.array(events_m50_10mbar).flatten()

plt.clf()
plt.hist(events_allch, bins=range(0, 1000))
plt.yscale("log")
plt.xlim([0, 1000])
plt.xlabel("Energy [ADU]")
plt.ylabel("Occurrences")
plt.title("Muon acquisition with THR 130 @ -50 °C and 10 mbar (all channels)")
plt.show()

# %%
# Comparison plot at -50C and 3, 6, 10 mbar

events_m50_3mbar = read_data("events_m50_3mbar", cache_folder)
events_m50_6mbar = read_data("events_m50_6mbar", cache_folder)
events_m50_10mbar = read_data("events_m50_10mbar", cache_folder)

channels = range(0, 32)
matplotlib.rcParams["figure.figsize"] = [8, 6]

events_allch_m50_3mbar = np.array(events_m50_3mbar).flatten()
events_allch_m50_6mbar = np.array(events_m50_6mbar).flatten()
events_allch_m50_10mbar = np.array(events_m50_10mbar).flatten()

store_data(events_allch_m50_3mbar, "events_allch_m50_3mbar", cache_folder)
store_data(events_allch_m50_6mbar, "events_allch_m50_6mbar", cache_folder)
store_data(events_allch_m50_10mbar, "events_allch_m50_10mbar", cache_folder)

plt.clf()
plt.hist(
    events_allch_m50_3mbar,
    bins=range(0, 1000, 5),
    edgecolor="blue",
    label="3 mbar",
    fc="None",
    histtype=u"step",
)
plt.hist(
    events_allch_m50_6mbar,
    bins=range(0, 1000, 5),
    edgecolor="red",
    label="6 mbar",
    fc="None",
    histtype=u"step",
)
plt.hist(
    events_allch_m50_10mbar,
    bins=range(0, 1000, 5),
    edgecolor="green",
    label="10 mbar",
    fc="None",
    histtype=u"step",
)
plt.yscale("log")
plt.xlim([0, 1000])
plt.xlabel("Energy [ADU]")
plt.ylabel("Occurrences")
plt.title("Muon acquisition with THR 130 @ -50 °C (all channels)")
plt.legend(loc="upper right")
plt.grid(alpha=0.3)
plt.show()

plt.clf()
plt.hist(
    events_allch_m50_3mbar,
    bins=range(0, 1000, 5),
    edgecolor="blue",
    label="3 mbar",
    fc="None",
    histtype=u"step",
)
plt.hist(
    events_allch_m50_6mbar,
    bins=range(0, 1000, 5),
    edgecolor="red",
    label="6 mbar",
    fc="None",
    histtype=u"step",
)
plt.hist(
    events_allch_m50_10mbar,
    bins=range(0, 1000, 5),
    edgecolor="green",
    label="10 mbar",
    fc="None",
    histtype=u"step",
)
plt.xlim([0, 1000])
plt.xlabel("Energy [ADU]")
plt.ylabel("Occurrences")
plt.title("Muon acquisition with THR 130 @ -50 °C (all channels)")
plt.legend(loc="upper right")
plt.grid(alpha=0.3)
plt.show()

# %%
# Plot muons as sum of all channels
events_m40_3mbar = read_data("events_m40_3mbar", cache_folder)
channels = range(0, 32)
matplotlib.rcParams["figure.figsize"] = [8, 6]

events_allch = np.array(events_m40_3mbar).flatten()

plt.clf()
plt.hist(events_allch, bins=range(0, 1000))
plt.yscale("log")
plt.xlim([0, 1000])
plt.xlabel("Energy [ADU]")
plt.ylabel("Occurrences")
plt.title("Muon acquisition with THR 130 @ -40 °C and 3 mbar (all channels)")
plt.show()

# %%
# Plot muons as sum of all channels
events_m40_6mbar = read_data("events_m40_6mbar", cache_folder)
channels = range(0, 32)
matplotlib.rcParams["figure.figsize"] = [8, 6]

events_allch = np.array(events_m40_6mbar).flatten()

plt.clf()
plt.hist(events_allch, bins=range(0, 1000))
plt.yscale("log")
plt.xlim([0, 1000])
plt.xlabel("Energy [ADU]")
plt.ylabel("Occurrences")
plt.title("Muon acquisition with THR 130 @ -40 °C and 6 mbar (all channels)")
plt.show()

# %%
# Plot muons as sum of all channels
events_m40_10mbar = read_data("events_m40_10mbar", cache_folder)
channels = range(0, 32)
matplotlib.rcParams["figure.figsize"] = [8, 6]

events_allch = np.array(events_m40_10mbar).flatten()

plt.clf()
plt.hist(events_allch, bins=range(0, 1000))
plt.yscale("log")
plt.xlim([0, 1000])
plt.xlabel("Energy [ADU]")
plt.ylabel("Occurrences")
plt.title("Muon acquisition with THR 130 @ -40 °C and 10 mbar (all channels)")
plt.show()

# %%
# Comparison plot at -40C and 3, 6, 10 mbar

events_m40_3mbar = read_data("events_m40_3mbar", cache_folder)
events_m40_6mbar = read_data("events_m40_6mbar", cache_folder)
events_m40_10mbar = read_data("events_m40_10mbar", cache_folder)

channels = range(0, 32)
matplotlib.rcParams["figure.figsize"] = [8, 6]

events_allch_m40_3mbar = np.array(events_m40_3mbar).flatten()
events_allch_m40_6mbar = np.array(events_m40_6mbar).flatten()
events_allch_m40_10mbar = np.array(events_m40_10mbar).flatten()

store_data(events_allch_m40_3mbar, "events_allch_m40_3mbar", cache_folder)
store_data(events_allch_m40_6mbar, "events_allch_m40_6mbar", cache_folder)
store_data(events_allch_m40_10mbar, "events_allch_m40_10mbar", cache_folder)

plt.clf()
plt.hist(
    events_allch_m40_3mbar,
    bins=range(0, 1000, 5),
    edgecolor="blue",
    label="3 mbar",
    fc="None",
    histtype=u"step",
)
plt.hist(
    events_allch_m40_6mbar,
    bins=range(0, 1000, 5),
    edgecolor="red",
    label="6 mbar",
    fc="None",
    histtype=u"step",
)
plt.hist(
    events_allch_m40_10mbar,
    bins=range(0, 1000, 5),
    edgecolor="green",
    label="10 mbar",
    fc="None",
    histtype=u"step",
)
plt.yscale("log")
plt.xlim([0, 1000])
plt.xlabel("Energy [ADU]")
plt.ylabel("Occurrences")
plt.title("Muon acquisition with THR 130 @ -40 °C (all channels)")
plt.legend(loc="upper right")
plt.grid(alpha=0.3)
plt.show()

plt.clf()
plt.hist(
    events_allch_m50_3mbar,
    bins=range(0, 1000, 5),
    edgecolor="blue",
    label="3 mbar",
    fc="None",
    histtype=u"step",
)
plt.hist(
    events_allch_m50_6mbar,
    bins=range(0, 1000, 5),
    edgecolor="red",
    label="6 mbar",
    fc="None",
    histtype=u"step",
)
plt.hist(
    events_allch_m50_10mbar,
    bins=range(0, 1000, 5),
    edgecolor="green",
    label="10 mbar",
    fc="None",
    histtype=u"step",
)
plt.xlim([0, 1000])
plt.xlabel("Energy [ADU]")
plt.ylabel("Occurrences")
plt.title("Muon acquisition with THR 130 @ -40 °C (all channels)")
plt.legend(loc="upper right")
plt.grid(alpha=0.3)
plt.show()

# %%
# Comparsion between -50C and -40C at 3 mbar

events_allch_m50_3mbar = read_data("events_allch_m50_3mbar", cache_folder)
events_allch_m40_3mbar = read_data("events_allch_m40_3mbar", cache_folder)

plt.clf()
plt.hist(
    events_allch_m50_3mbar,
    bins=range(0, 1000, 5),
    edgecolor="blue",
    label="-50 °C",
    fc="None",
    histtype=u"step",
)
plt.hist(
    events_allch_m40_3mbar,
    bins=range(0, 1000, 5),
    edgecolor="red",
    label="-40 °C",
    fc="None",
    histtype=u"step",
)
plt.xlim([0, 1000])
plt.xlabel("Energy [ADU]")
plt.ylabel("Occurrences")
plt.title("Muon acquisition with THR 130 @ 3 mbar (all channels)")
plt.legend(loc="upper right")
plt.grid(alpha=0.3)
plt.yscale("log")
plt.show()

plt.clf()
plt.hist(
    events_allch_m50_3mbar,
    bins=range(0, 1000, 5),
    edgecolor="blue",
    label="-50 °C",
    fc="None",
    histtype=u"step",
)
plt.hist(
    events_allch_m40_3mbar,
    bins=range(0, 1000, 5),
    edgecolor="red",
    label="-40 °C",
    fc="None",
    histtype=u"step",
)
plt.xlim([0, 1000])
plt.xlabel("Energy [ADU]")
plt.ylabel("Occurrences")
plt.title("Muon acquisition with THR 130 @ 3 mbar (all channels)")
plt.legend(loc="upper right")
plt.grid(alpha=0.3)
plt.show()

# %%
# Comparsion between -50C and -40C at 6 mbar

events_allch_m50_6mbar = read_data("events_allch_m50_6mbar", cache_folder)
events_allch_m40_6mbar = read_data("events_allch_m40_6mbar", cache_folder)

plt.clf()
plt.hist(
    events_allch_m50_6mbar,
    bins=range(0, 1000, 5),
    edgecolor="blue",
    label="-50 °C",
    fc="None",
    histtype=u"step",
)
plt.hist(
    events_allch_m40_6mbar,
    bins=range(0, 1000, 5),
    edgecolor="red",
    label="-40 °C",
    fc="None",
    histtype=u"step",
)
plt.xlim([0, 1000])
plt.xlabel("Energy [ADU]")
plt.ylabel("Occurrences")
plt.title("Muon acquisition with THR 130 @ 6 mbar (all channels)")
plt.legend(loc="upper right")
plt.grid(alpha=0.3)
plt.yscale("log")
plt.show()

plt.clf()
plt.hist(
    events_allch_m50_3mbar,
    bins=range(0, 1000, 5),
    edgecolor="blue",
    label="-50 °C",
    fc="None",
    histtype=u"step",
)
plt.hist(
    events_allch_m40_3mbar,
    bins=range(0, 1000, 5),
    edgecolor="red",
    label="-40 °C",
    fc="None",
    histtype=u"step",
)
plt.xlim([0, 1000])
plt.xlabel("Energy [ADU]")
plt.ylabel("Occurrences")
plt.title("Muon acquisition with THR 130 @ 6 mbar (all channels)")
plt.legend(loc="upper right")
plt.grid(alpha=0.3)
plt.show()

# %%
# Comparsion between -50C and -40C at 10 mbar

events_allch_m50_10mbar = read_data("events_allch_m50_10mbar", cache_folder)
events_allch_m40_10mbar = read_data("events_allch_m40_10mbar", cache_folder)

plt.clf()
plt.hist(
    events_allch_m50_10mbar,
    bins=range(0, 1000, 5),
    edgecolor="blue",
    label="-50 °C",
    fc="None",
    histtype=u"step",
)
plt.hist(
    events_allch_m40_10mbar,
    bins=range(0, 1000, 5),
    edgecolor="red",
    label="-40 °C",
    fc="None",
    histtype=u"step",
)
plt.xlim([0, 1000])
plt.xlabel("Energy [ADU]")
plt.ylabel("Occurrences")
plt.title("Muon acquisition with THR 130 @ 10 mbar (all channels)")
plt.legend(loc="upper right")
plt.grid(alpha=0.3)
plt.yscale("log")
plt.show()

plt.clf()
plt.hist(
    events_allch_m50_10mbar,
    bins=range(0, 1000, 5),
    edgecolor="blue",
    label="-50 °C",
    fc="None",
    histtype=u"step",
)
plt.hist(
    events_allch_m40_10mbar,
    bins=range(0, 1000, 5),
    edgecolor="red",
    label="-40 °C",
    fc="None",
    histtype=u"step",
)
plt.xlim([0, 1000])
plt.xlabel("Energy [ADU]")
plt.ylabel("Occurrences")
plt.title("Muon acquisition with THR 130 @ 10 mbar (all channels)")
plt.legend(loc="upper right")
plt.grid(alpha=0.3)
plt.show()
